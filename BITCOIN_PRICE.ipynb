# %% [markdown]
# <a href="https://colab.research.google.com/github/SHASHANK8412/BITCOIN-PRICE-PREDICTION/blob/main/BITCOIN_PRICE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

# %% [markdown]
# Loading Dataset

# %%
df=pd.read_csv('btcNewsToPrice.csv')

# %% [markdown]
# Combine news Headlines

# %%
text_cols = [col for col in df.columns if col.startswith("top_")]

df["news_text"] = df[text_cols].fillna("").agg(" ".join, axis=1)

# %% [markdown]
# Define Dependent and Independent variable

# %%
X = df["news_text"]
y = df["price"]

# %% [markdown]
# Convert Text to numbers

# %%
vectorizer = TfidfVectorizer(
    max_features=3000,
    stop_words="english"
)

X = vectorizer.fit_transform(X)
